# %%
#Global Configuration for Pharma sales Pipeline

#File Path (Uploaded CSV Files)
CSV_PATH = "/Volumes/dev/spark_db/datasets/Pharmacy Dataset/pharma_sales.csv"

#Database /Schema Name
DB_NAME = 'Pharma_db'

#Tabke Name
RAW_TABLE = "pharma_raw"
CLEAN_TABLE = "pharma_clean"

# Pipeline run date
from datetime import date

RUN_DATE = str(date.today())

print(f'Config loaded. Run date: {RUN_DATE}')
print(f'Source: {CSV_PATH}')
